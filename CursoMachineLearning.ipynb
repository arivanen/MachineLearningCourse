# %%
# !pip install plotly --upgrade
# Out:
# Requirement already up-to-date: plotly in c:\users\user\anaconda3\lib\site-packages (5.0.0)
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
base_credit = pd.read_csv("C:\\Users\\User\\credit_data.csv")

# %%
base_credit # defaulted
# Out:
#       clientid        income        age          loan  default
# 0            1  66155.925095  59.017015   8106.532131        0
# 1            2  34415.153966  48.117153   6564.745018        0
# 2            3  57317.170063  63.108049   8020.953296        0
# 3            4  42709.534201  45.751972   6103.642260        0
# 4            5  66952.688845  18.584336   8770.099235        1
# 5            6  24904.064140  57.471607     15.498598        0
# 6            7  48430.359613  26.809132   5722.581981        0
# 7            8  24500.141984  32.897548   2971.003310        1
# 8            9  40654.892537  55.496853   4755.825280        0
# 9           10  25075.872771  39.776378   1409.230371        0
# 10          11  64131.415372  25.679575   4351.028971        0
# 11          12  59436.847123  60.471936   9254.244538        0
# 12          13  61050.346079  26.355044   5893.264659        0
# 13          14  27267.995458  61.576776   4759.787581        0
# ...

# %%
base_credit.tail()
# Out:
#       clientid        income        age         loan  default
# 1995      1996  59221.044874  48.518179  1926.729397        0
# 1996      1997  69516.127573  23.162104  3503.176156        0
# 1997      1998  44311.449262  28.017167  5522.786693        1
# 1998      1999  43756.056605  63.971796  1622.722598        0
# 1999      2000  69436.579552  56.152617  7378.833599        0

# %%
base_credit.describe()
# Out:
#           clientid        income          age          loan      default
# count  2000.000000   2000.000000  1997.000000   2000.000000  2000.000000
# mean   1000.500000  45331.600018    40.807559   4444.369695     0.141500
# std     577.494589  14326.327119    13.624469   3045.410024     0.348624
# min       1.000000  20014.489470   -52.423280      1.377630     0.000000
# 25%     500.750000  32796.459717    28.990415   1939.708847     0.000000
# 50%    1000.500000  45789.117313    41.317159   3974.719419     0.000000
# 75%    1500.250000  57791.281668    52.587040   6432.410625     0.000000
# max    2000.000000  69995.685578    63.971796  13766.051239     1.000000

# %%
np.unique(base_credit['default'])
# Out:
# array([0, 1], dtype=int64)

# %%
np.unique(base_credit['default'], return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([1717,  283], dtype=int64))

# %%
sns.countplot(x= base_credit['default']);

# %%
base_credit.loc[base_credit['age'] <0 ]
# Out:
#     clientid        income        age         loan  default
# 15        16  50501.726689 -28.218361  3977.287432        0
# 21        22  32197.620701 -52.423280  4244.057136        0
# 26        27  63287.038908 -36.496976  9595.286289        0

# %%
# Apagar a coluna inteira (todos os registros da base de dados)
base_credit2= base_credit.drop('age', axis=1)
base_credit2
# Out:
#       clientid        income          loan  default
# 0            1  66155.925095   8106.532131        0
# 1            2  34415.153966   6564.745018        0
# 2            3  57317.170063   8020.953296        0
# 3            4  42709.534201   6103.642260        0
# 4            5  66952.688845   8770.099235        1
# 5            6  24904.064140     15.498598        0
# 6            7  48430.359613   5722.581981        0
# 7            8  24500.141984   2971.003310        1
# 8            9  40654.892537   4755.825280        0
# 9           10  25075.872771   1409.230371        0
# 10          11  64131.415372   4351.028971        0
# 11          12  59436.847123   9254.244538        0
# 12          13  61050.346079   5893.264659        0
# 13          14  27267.995458   4759.787581        0
# 14          15  63061.960174   1850.369377        0
# 15          16  50501.726689   3977.287432        0
# 16          17  43548.654711   3935.544453        0
# ...

# %%
# Apagar somente os registros com valores inconsistentes -> não está apagando a coluna inteira, apenas os valores menor que 0
base_credit3 = base_credit.drop(base_credit[base_credit['age'] < 0].index)
base_credit3
# Out:
#       clientid        income        age          loan  default
# 0            1  66155.925095  59.017015   8106.532131        0
# 1            2  34415.153966  48.117153   6564.745018        0
# 2            3  57317.170063  63.108049   8020.953296        0
# 3            4  42709.534201  45.751972   6103.642260        0
# 4            5  66952.688845  18.584336   8770.099235        1
# 5            6  24904.064140  57.471607     15.498598        0
# 6            7  48430.359613  26.809132   5722.581981        0
# 7            8  24500.141984  32.897548   2971.003310        1
# 8            9  40654.892537  55.496853   4755.825280        0
# 9           10  25075.872771  39.776378   1409.230371        0
# 10          11  64131.415372  25.679575   4351.028971        0
# 11          12  59436.847123  60.471936   9254.244538        0
# 12          13  61050.346079  26.355044   5893.264659        0
# 13          14  27267.995458  61.576776   4759.787581        0
# ...

# %%
# Preencher os valores inconsistentes manualmente (é a forma mais confiável, mas quando há muitos registros inconsistente é inviável)
# Preenchera média

base_credit['age'][base_credit['age'] > 0].mean()
# Out:
# 40.92770044906149

# %%
base_credit.loc[base_credit['age'] < 0, 'age'] = 40.927700

# %%
base_credit.head(27)
# Out:
#     clientid        income        age         loan  default
# 0          1  66155.925095  59.017015  8106.532131        0
# 1          2  34415.153966  48.117153  6564.745018        0
# 2          3  57317.170063  63.108049  8020.953296        0
# 3          4  42709.534201  45.751972  6103.642260        0
# 4          5  66952.688845  18.584336  8770.099235        1
# 5          6  24904.064140  57.471607    15.498598        0
# 6          7  48430.359613  26.809132  5722.581981        0
# 7          8  24500.141984  32.897548  2971.003310        1
# 8          9  40654.892537  55.496853  4755.825280        0
# 9         10  25075.872771  39.776378  1409.230371        0
# 10        11  64131.415372  25.679575  4351.028971        0
# 11        12  59436.847123  60.471936  9254.244538        0
# 12        13  61050.346079  26.355044  5893.264659        0
# 13        14  27267.995458  61.576776  4759.787581        0
# 14        15  63061.960174  39.201553  1850.369377        0
# ...

# %%
#Verificar valores faltantes
base_credit.isnull()
# Out:
#       clientid  income    age   loan  default
# 0        False   False  False  False    False
# 1        False   False  False  False    False
# 2        False   False  False  False    False
# 3        False   False  False  False    False
# 4        False   False  False  False    False
# 5        False   False  False  False    False
# 6        False   False  False  False    False
# 7        False   False  False  False    False
# 8        False   False  False  False    False
# 9        False   False  False  False    False
# 10       False   False  False  False    False
# 11       False   False  False  False    False
# 12       False   False  False  False    False
# 13       False   False  False  False    False
# 14       False   False  False  False    False
# 15       False   False  False  False    False
# 16       False   False  False  False    False
# 17       False   False  False  False    False
# 18       False   False  False  False    False
# ...

# %%
base_credit.isnull().sum()
# Out:
# clientid    0
# income      0
# age         3
# loan        0
# default     0
# dtype: int64

# %%
base_credit.loc[pd.isnull(base_credit['age'])]
# Out:
#     clientid        income  age         loan  default
# 28        29  59417.805406  NaN  2082.625938        0
# 30        31  48528.852796  NaN  6155.784670        0
# 31        32  23526.302555  NaN  2862.010139        0

# %%
base_credit['age'].fillna(base_credit['age'].mean(), inplace= True)

# %%
base_credit.loc[(base_credit['clientid'] == 29)]
# Out:
#     clientid        income      age         loan  default
# 28        29  59417.805406  40.9277  2082.625938        0

# %%
base_credit.loc[base_credit['clientid'].isin([29, 31, 32])]
# Out:
#     clientid        income      age         loan  default
# 28        29  59417.805406  40.9277  2082.625938        0
# 30        31  48528.852796  40.9277  6155.784670        0
# 31        32  23526.302555  40.9277  2862.010139        0

# %%
df= base_credit

# %%
df.to_csv(r'C:\\Users\\User\\credit_data_tratado.csv')

# %%
credit_data_tratado= pd.read_csv("C:\\Users\\User\\credit_data_tratado.csv")
credit_data_tratado
# Out:
#       Unnamed: 0  clientid        income        age          loan  default
# 0              0         1  66155.925095  59.017015   8106.532131        0
# 1              1         2  34415.153966  48.117153   6564.745018        0
# 2              2         3  57317.170063  63.108049   8020.953296        0
# 3              3         4  42709.534201  45.751972   6103.642260        0
# 4              4         5  66952.688845  18.584336   8770.099235        1
# 5              5         6  24904.064140  57.471607     15.498598        0
# 6              6         7  48430.359613  26.809132   5722.581981        0
# 7              7         8  24500.141984  32.897548   2971.003310        1
# 8              8         9  40654.892537  55.496853   4755.825280        0
# 9              9        10  25075.872771  39.776378   1409.230371        0
# 10            10        11  64131.415372  25.679575   4351.028971        0
# ...
